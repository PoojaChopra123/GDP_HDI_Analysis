# %%
# %matplotlib notebook
# %matplotlib inline

# %%
import csv 
import matplotlib.pyplot as plt
import requests
import pandas as pd
import numpy as np
from pprint import pprint
from scipy.stats import linregress
import math

# %%
csv1 = "hpi-data-2016.csv"
csv2 = "HDI_2016_Statistical_Annex_Table_1.csv"
csv3 = "Human development index (HDI)_historical.csv"
csv4 = "financial_data.csv"

# %%
#human happiness complete data 
hpi_complete_data = pd.read_csv(csv1, encoding="ISO-8859-1")

#human development index 
hdi_statistical_data = pd.read_csv(csv2)
hdi_historical_data = pd.read_csv(csv3, encoding="ISO-8859-1", skiprows=1)
financial_data = pd.read_csv(csv4, encoding="ISO-8859-1")

#df_columns = hdi_historical_data.columns
#df_years = df_columns[2:]

# %%
# df4 = pd.pivot_table(df2,values='Value', index='Date', columns='Type'])

# %%
hdi_historical = hdi_historical_data.dropna(axis=0, how="all").dropna(axis=1, how= "all")

#hdi historical rank sorted
hdi_historical_sorted_rank = hdi_historical.sort_values(by=["HDI Rank (2015)"])
hdi_historical_sorted_rank.head()
# Out:
#      HDI Rank (2015)       Country   1990   1991   1992   1993   1994   1995  \
# 124                1        Norway  0.849  0.855  0.862  0.870  0.884  0.883
# 8                  2     Australia  0.866  0.867  0.871  0.874  0.876  0.885
# 162                2   Switzerland  0.831  0.833  0.835  0.840  0.842  0.846
# 63                 4       Germany  0.801  0.809  0.814  0.822  0.828  0.834
# 150                5     Singapore  0.718  0.729  0.740  0.751  0.763  0.773
#
#       1996   1997  ...     2006   2007   2008   2009   2010   2011   2012  \
# 124  0.888  0.895  ...    0.934  0.936  0.936  0.936  0.939  0.941  0.942
# 8    0.888  0.891  ...    0.918  0.921  0.925  0.927  0.927  0.930  0.933
# 162  0.853  0.863  ...    0.911  0.914  0.916  0.920  0.932  0.932  0.934
# 63   0.840  0.845  ...    0.898  0.903  0.906  0.907  0.912  0.916  0.919
# 150  0.783  0.795  ...    0.873  0.880  0.887  0.889  0.911  0.917  0.920
#
#       2013   2014   2015
# 124  0.945  0.948  0.949
# 8    0.936  0.937  0.939
# 162  0.936  0.938  0.939
# 63   0.920  0.924  0.926
# 150  0.922  0.924  0.925
#
# [5 rows x 28 columns]

# %%
#hpi_data.dropna(axis=[0,1], how='all')

#human happiness index dropped NaN
hpi_df = hpi_complete_data.dropna(axis=0, how='all').dropna(axis=1, how='all')
hpi_df.head()
# Out:
#    HPI Rank      Country                        Region  \
# 0     110.0  Afghanistan  Middle East and North Africa
# 1      13.0      Albania                Post-communist
# 2      30.0      Algeria  Middle East and North Africa
# 3      19.0    Argentina                      Americas
# 4      73.0      Armenia                Post-communist
#
#    Average Life \nExpectancy  Average Wellbeing\n(0-10)  Happy Life Years  \
# 0                       59.7                        3.8              12.4
# 1                       77.3                        5.5              34.4
# 2                       74.3                        5.6              30.5
# 3                       75.9                        6.5              40.2
# 4                       74.4                        4.3              24.0
#
#    Footprint\n(gha/capita) Inequality of Outcomes  \
# 0                      0.8                    43%
# 1                      2.2                    17%
# 2                      2.1                    24%
# 3                      3.1                    16%
# 4                      2.2                    22%
#
#    Inequality-adjusted Life Expectancy  Inequality-adjusted Wellbeing  \
# 0                                 38.3                            3.4
# 1                                 69.7                            5.1
# 2                                 60.5                            5.2
# 3                                 68.3                            6.0
# 4                                 66.9                            3.7
#
#    Happy Planet Index  GDP/capita  Population        GINI index
# 0                20.2       691.0  29,726,803  Data unavailable
# 1                36.8      4247.0   2,900,489                29
# 2                33.3      5584.0  37,439,427  Data unavailable
# 3                35.2     14357.0  42,095,224              42.5
# 4                25.7      3566.0   2,978,339              30.5

# %%
#human development index statistical data dropped NaN
hdi_stat = hdi_statistical_data.dropna(axis=0, how='all').dropna(axis=1, how='all')

#merged dataframes-- hdi statistical and hpi on country name
merged_df= pd.merge(hdi_stat, hpi_df, on = "Country")


#####merge hdi statistical with GNH (gross national happiness) index by country name.

# %%
merged_df.head()
# Out:
#    HDI rank      Country  Human Development Index (HDI)   \
# 0         1       Norway                           0.949
# 1         2    Australia                           0.939
# 2         2  Switzerland                           0.939
# 3         4      Germany                           0.926
# 4         5      Denmark                           0.925
#
#    Life expectancy at birth  Expected years of schooling   \
# 0                      81.7                          17.7
# 1                      82.5                          20.4
# 2                      83.1                          16.0
# 3                      81.1                          17.1
# 4                      80.4                          19.2
#
#    Mean years of schooling Gross national income (GNI) per capita  \
# 0                     12.7                                 67,614
# 1                     13.2                                 42,822
# 2                     13.4                                 56,364
# 3                     13.2                                 45,000
# 4                     12.7                                 44,519
#
#    GNI per capita rank minus HDI rank  HDI rank.1 Development Bucket  \
# 0                                   5           1          VERY HIGH
# 1                                  19           3          VERY HIGH
# 2                                   7           2          VERY HIGH
# 3                                  13           4          VERY HIGH
# 4                                  13           6          VERY HIGH
#
#          ...         Average Wellbeing\n(0-10) Happy Life Years  \
# 0        ...                               7.7             57.1
# 1        ...                               7.2             53.1
# 2        ...                               7.8             59.3
# 3        ...                               6.7             48.2
# 4        ...                               7.5             54.4
#
#    Footprint\n(gha/capita)  Inequality of Outcomes  \
# 0                      5.0                      7%
# 1                      9.3                      8%
# 2                      5.8                      6%
# 3                      5.3                      8%
# 4                      5.5                      7%
#
#    Inequality-adjusted Life Expectancy  Inequality-adjusted Wellbeing  \
# 0                                 78.6                            7.4
# 1                                 78.6                            6.9
# 2                                 79.4                            7.6
# 3                                 77.6                            6.4
# 4                                 76.8                            7.2
#
#   Happy Planet Index  GDP/capita  Population        GINI index
# 0               36.8   $101,564    5,018,573              25.9
# 1               21.2    $67,646   22,728,254  Data unavailable
# 2               34.3    $83,209    7,996,861              31.6
# 3               29.8    $44,011   80,425,823  Data unavailable
# 4               32.7    $57,636    5,591,572              29.1
#
# [5 rows x 23 columns]

# %%
grouped_df = merged_df.groupby(['Development Bucket'])
#yes_df = pd.DataFrame(grouped_df.mean(), index = ['LOW', 'MEDIUM', 'HIGH', 'VERY HIGH'])

grouped_df.mean()
# Out:
#                       HDI rank  Human Development Index (HDI)   \
# Development Bucket
# HIGH                 77.588235                        0.756441
# LOW                 168.423077                        0.467346
# MEDIUM              126.785714                        0.631107
# VERY HIGH            24.605263                        0.882447
#
#                     Life expectancy at birth  Expected years of schooling   \
# Development Bucket
# HIGH                               74.567647                     13.935294
# LOW                                59.257692                      9.515385
# MEDIUM                             68.425000                     11.592857
# VERY HIGH                          80.155263                     16.592105
#
#                     Mean years of schooling  \
# Development Bucket
# HIGH                               9.444118
# LOW                                4.130769
# MEDIUM                             6.964286
# VERY HIGH                         11.821053
#
#                     GNI per capita rank minus HDI rank  HDI rank.1  \
# Development Bucket
# HIGH                                          5.117647   77.794118
# LOW                                           0.461538  168.423077
# MEDIUM                                       -2.857143  126.857143
# VERY HIGH                                     8.921053   24.815789
#
#                       HPI Rank  Average Life \nExpectancy  \
# Development Bucket
# HIGH                 52.852941                  73.955882
# LOW                 111.307692                  57.796154
# MEDIUM               61.071429                  67.507143
# VERY HIGH            59.473684                  79.571053
#
#                     Average Wellbeing\n(0-10)  Happy Life Years  \
# Development Bucket
# HIGH                                 5.641176         32.735294
# LOW                                  4.192308         13.588462
# MEDIUM                               4.975000         23.375000
# VERY HIGH                            6.463158         45.302632
#
#                     Footprint\n(gha/capita)  \
# Development Bucket
# HIGH                               3.223529
# LOW                                1.269231
# MEDIUM                             1.935714
# VERY HIGH                          5.531579
#
#                     Inequality-adjusted Life Expectancy  \
# Development Bucket
# HIGH                                          65.485294
# LOW                                           37.869231
# MEDIUM                                        53.285714
# VERY HIGH                                     76.052632
#
#                     Inequality-adjusted Wellbeing  Happy Planet Index
# Development Bucket
# HIGH                                     5.161765           29.764706
# LOW                                      3.769231           19.184615
# MEDIUM                                   4.517857           28.075000
# VERY HIGH                                6.084211           28.044737

# %%
new_df = grouped_df.mean().reset_index()

#new_df

new_df['Development Bucket'] = pd.Categorical(new_df['Development Bucket'], ["LOW", "MEDIUM", "HIGH", "VERY HIGH"])

new_df.sort_values("Development Bucket")

new_df.reindex([1,2,0,3])

new_df
# Out:
#   Development Bucket    HDI rank  Human Development Index (HDI)   \
# 0               HIGH   77.588235                        0.756441
# 1                LOW  168.423077                        0.467346
# 2             MEDIUM  126.785714                        0.631107
# 3          VERY HIGH   24.605263                        0.882447
#
#    Life expectancy at birth  Expected years of schooling   \
# 0                 74.567647                     13.935294
# 1                 59.257692                      9.515385
# 2                 68.425000                     11.592857
# 3                 80.155263                     16.592105
#
#    Mean years of schooling  GNI per capita rank minus HDI rank  HDI rank.1  \
# 0                 9.444118                            5.117647   77.794118
# 1                 4.130769                            0.461538  168.423077
# 2                 6.964286                           -2.857143  126.857143
# 3                11.821053                            8.921053   24.815789
#
#      HPI Rank  Average Life \nExpectancy  Average Wellbeing\n(0-10)  \
# 0   52.852941                  73.955882                   5.641176
# 1  111.307692                  57.796154                   4.192308
# 2   61.071429                  67.507143                   4.975000
# 3   59.473684                  79.571053                   6.463158
#
#    Happy Life Years  Footprint\n(gha/capita)  \
# 0         32.735294                 3.223529
# 1         13.588462                 1.269231
# 2         23.375000                 1.935714
# 3         45.302632                 5.531579
#
#    Inequality-adjusted Life Expectancy  Inequality-adjusted Wellbeing  \
# 0                            65.485294                       5.161765
# 1                            37.869231                       3.769231
# 2                            53.285714                       4.517857
# 3                            76.052632                       6.084211
#
#    Happy Planet Index
# 0           29.764706
# 1           19.184615
# 2           28.075000
# 3           28.044737

# %%
df2 = pd.DataFrame({
    'Development Bucket': ['LOW', 'MEDIUM', 'HIGH', 'VERY HIGH'],
    'num': [0, 1, 2, 3]})
df3 = pd.merge(new_df, df2, on='Development Bucket')
df3 = df3.sort_values('num')

df3

#df3.plot(kind='bar', x='Development Bucket', y='Life expectancy at birth')
# Out:
#   Development Bucket    HDI rank  Human Development Index (HDI)   \
# 1                LOW  168.423077                        0.467346
# 2             MEDIUM  126.785714                        0.631107
# 0               HIGH   77.588235                        0.756441
# 3          VERY HIGH   24.605263                        0.882447
#
#    Life expectancy at birth  Expected years of schooling   \
# 1                 59.257692                      9.515385
# 2                 68.425000                     11.592857
# 0                 74.567647                     13.935294
# 3                 80.155263                     16.592105
#
#    Mean years of schooling  GNI per capita rank minus HDI rank  HDI rank.1  \
# 1                 4.130769                            0.461538  168.423077
# 2                 6.964286                           -2.857143  126.857143
# 0                 9.444118                            5.117647   77.794118
# 3                11.821053                            8.921053   24.815789
#
#      HPI Rank  Average Life \nExpectancy  Average Wellbeing\n(0-10)  \
# 1  111.307692                  57.796154                   4.192308
# 2   61.071429                  67.507143                   4.975000
# 0   52.852941                  73.955882                   5.641176
# 3   59.473684                  79.571053                   6.463158
#
#    Happy Life Years  Footprint\n(gha/capita)  \
# 1         13.588462                 1.269231
# 2         23.375000                 1.935714
# 0         32.735294                 3.223529
# 3         45.302632                 5.531579
#
#    Inequality-adjusted Life Expectancy  Inequality-adjusted Wellbeing  \
# 1                            37.869231                       3.769231
# 2                            53.285714                       4.517857
# 0                            65.485294                       5.161765
# 3                            76.052632                       6.084211
#
#    Happy Planet Index  num
# 1           19.184615    0
# 2           28.075000    1
# 0           29.764706    2
# 3           28.044737    3

# %%
plt.title("Life Expectancy by HDI Bucket")
plt.xlabel("Development Bucket")
plt.ylabel("Years")

plt.ylim(50,90)


plt.bar(df3["Development Bucket"], df3["Life expectancy at birth"])

#####df3.plot(kind='bar',x='Development Bucket',y='Life expectancy at birth')


plt.show()

# %%
#merged dataframes-- hdi statistical and hpi on country name
finan_df = financial_data.dropna(axis=0, how='all').dropna(axis=1, how='all')
merged_df2= pd.merge(merged_df, finan_df, on = "Country")
merged_df2
# Out:
#      HDI rank         Country  Human Development Index (HDI)   \
# 0           1          Norway                           0.949
# 1           2       Australia                           0.939
# 2           2     Switzerland                           0.939
# 3           4         Germany                           0.926
# 4           5         Denmark                           0.925
# 5           7     Netherlands                           0.924
# 6           8         Ireland                           0.923
# 7           9         Iceland                           0.921
# 8          10          Canada                           0.920
# 9          13     New Zealand                           0.915
# 10         14          Sweden                           0.913
# 11         16  United Kingdom                           0.909
# 12         17           Japan                           0.903
# 13         19          Israel                           0.899
# 14         20      Luxembourg                           0.898
# 15         21          France                           0.897
# 16         22         Belgium                           0.896
# 17         23         Finland                           0.895
# 18         24         Austria                           0.893
# 19         25        Slovenia                           0.890
# 20         26           Italy                           0.887
# 21         27           Spain                           0.884
# 22         28  Czech Republic                           0.878
# 23         29          Greece                           0.866
# 24         30         Estonia                           0.865
# 25         33          Cyprus                           0.856
# 26         33           Malta                           0.856
# 27         36          Poland                           0.855
# 28         37       Lithuania                           0.848
# 29         38           Chile                           0.847
# ..        ...             ...                             ...
# 92        143        Cambodia                           0.563
# 93        144           Nepal                           0.558
# 94        145         Myanmar                           0.556
# 95        146           Kenya                           0.555
# 96        147        Pakistan                           0.550
# 97        148       Swaziland                           0.541
# 98        152         Nigeria                           0.527
# 99        153        Cameroon                           0.518
# 100       154        Zimbabwe                           0.516
# 101       157      Mauritania                           0.513
# 102       159          Rwanda                           0.498
# 103       160         Comoros                           0.497
# 104       160         Lesotho                           0.497
# 105       162         Senegal                           0.494
# 106       163           Haiti                           0.493
# 107       163          Uganda                           0.493
# 108       166            Togo                           0.487
# 109       167           Benin                           0.485
# 110       169     Afghanistan                           0.479
# 111       170          Malawi                           0.476
# 112       172        Djibouti                           0.473
# 113       174        Ethiopia                           0.448
# 114       177         Liberia                           0.427
# 115       179    Sierra Leone                           0.420
# 116       181      Mozambique                           0.418
# 117       183          Guinea                           0.414
# 118       184         Burundi                           0.404
# 119       185    Burkina Faso                           0.402
# 120       186            Chad                           0.396
# 121       187           Niger                           0.353
#
#      Life expectancy at birth  Expected years of schooling   \
# 0                        81.7                          17.7
# 1                        82.5                          20.4
# 2                        83.1                          16.0
# 3                        81.1                          17.1
# 4                        80.4                          19.2
# 5                        81.7                          18.1
# 6                        81.1                          18.6
# 7                        82.7                          19.0
# 8                        82.2                          16.3
# 9                        82.0                          19.2
# 10                       82.3                          16.1
# 11                       80.8                          16.3
# 12                       83.7                          15.3
# 13                       82.6                          16.0
# 14                       81.9                          13.9
# 15                       82.4                          16.3
# 16                       81.0                          16.6
# 17                       81.0                          17.0
# 18                       81.6                          15.9
# 19                       80.6                          17.3
# 20                       83.3                          16.3
# 21                       82.8                          17.7
# 22                       78.8                          16.8
# 23                       81.1                          17.2
# 24                       77.0                          16.5
# 25                       80.3                          14.3
# 26                       80.7                          14.6
# 27                       77.6                          16.4
# 28                       73.5                          16.5
# 29                       82.0                          16.3
# ..                        ...                           ...
# 92                       68.8                          10.9
# 93                       70.0                          12.2
# 94                       66.1                           9.1
# 95                       62.2                          11.1
# 96                       66.4                           8.1
# 97                       48.9                          11.4
# 98                       53.1                          10.0
# 99                       56.0                          10.4
# 100                      59.2                          10.3
# 101                      63.2                           8.5
# 102                      64.7                          10.8
# 103                      63.6                          11.1
# 104                      50.1                          10.7
# 105                      66.9                           9.5
# 106                      63.1                           9.1
# 107                      59.2                          10.0
# 108                      60.2                          12.0
# 109                      59.8                          10.7
# 110                      60.7                          10.1
# 111                      63.9                          10.8
# 112                      62.3                           6.3
# 113                      64.6                           8.4
# 114                      61.2                           9.9
# 115                      51.3                           9.5
# 116                      55.5                           9.1
# 117                      59.2                           8.8
# 118                      57.1                          10.6
# 119                      59.0                           7.7
# 120                      51.9                           7.3
# 121                      61.9                           5.4
#
#      Mean years of schooling Gross national income (GNI) per capita  \
# 0                       12.7                                 67,614
# 1                       13.2                                 42,822
# 2                       13.4                                 56,364
# 3                       13.2                                 45,000
# 4                       12.7                                 44,519
# 5                       11.9                                 46,326
# 6                       12.3                                 43,798
# 7                       12.2                                 37,065
# 8                       13.1                                 42,582
# 9                       12.5                                 32,870
# 10                      12.3                                 46,251
# 11                      13.3                                 37,931
# 12                      12.5                                 37,268
# 13                      12.8                                 31,215
# 14                      12.0                                 62,471
# 15                      11.6                                 38,085
# 16                      11.4                                 41,243
# 17                      11.2                                 38,868
# 18                      11.3                                 43,609
# 19                      12.1                                 28,664
# 20                      10.9                                 33,573
# 21                       9.8                                 32,779
# 22                      12.3                                 28,144
# 23                      10.5                                 24,808
# 24                      12.5                                 26,362
# 25                      11.7                                 29,459
# 26                      11.3                                 29,500
# 27                      11.9                                 24,117
# 28                      12.7                                 26,006
# 29                       9.9                                 21,665
# ..                       ...                                    ...
# 92                       4.7                                  3,095
# 93                       4.1                                  2,337
# 94                       4.7                                  4,943
# 95                       6.3                                  2,881
# 96                       5.1                                  5,031
# 97                       6.8                                  7,522
# 98                       6.0                                  5,443
# 99                       6.1                                  2,894
# 100                      7.7                                  1,588
# 101                      4.3                                  3,527
# 102                      3.8                                  1,617
# 103                      4.8                                  1,335
# 104                      6.1                                  3,319
# 105                      2.8                                  2,250
# 106                      5.2                                  1,657
# 107                      5.7                                  1,670
# 108                      4.7                                  1,262
# 109                      3.5                                  1,979
# 110                      3.6                                  1,871
# 111                      4.4                                  1,073
# 112                      4.1                                  3,216
# 113                      2.6                                  1,523
# 114                      4.4                                    683
# 115                      3.3                                  1,529
# 116                      3.5                                  1,098
# 117                      2.6                                  1,058
# 118                      3.0                                    691
# 119                      1.4                                  1,537
# 120                      2.3                                  1,991
# 121                      1.7                                    889
#
#      GNI per capita rank minus HDI rank  HDI rank.1 Development Bucket  \
# 0                                     5           1          VERY HIGH
# 1                                    19           3          VERY HIGH
# 2                                     7           2          VERY HIGH
# 3                                    13           4          VERY HIGH
# 4                                    13           6          VERY HIGH
# 5                                     8           6          VERY HIGH
# 6                                    11           8          VERY HIGH
# 7                                    20           9          VERY HIGH
# 8                                    12           9          VERY HIGH
# 9                                    20          13          VERY HIGH
# 10                                    2          15          VERY HIGH
# 11                                   10          16          VERY HIGH
# 12                                   10          17          VERY HIGH
# 13                                   16          19          VERY HIGH
# 14                                  -12          20          VERY HIGH
# 15                                    4          22          VERY HIGH
# 16                                    1          21          VERY HIGH
# 17                                    1          23          VERY HIGH
# 18                                   -4          24          VERY HIGH
# 19                                   13          25          VERY HIGH
# 20                                    6          27          VERY HIGH
# 21                                    7          26          VERY HIGH
# 22                                   11          28          VERY HIGH
# 23                                   16          29          VERY HIGH
# 24                                   12          31          VERY HIGH
# 25                                    4          34          VERY HIGH
# 26                                    3          35          VERY HIGH
# 27                                   11          36          VERY HIGH
# 28                                    7          37          VERY HIGH
# 29                                   16          38          VERY HIGH
# ..                                  ...         ...                ...
# 92                                   10         143             MEDIUM
# 93                                   19         144             MEDIUM
# 94                                   -6         146             MEDIUM
# 95                                   10         147             MEDIUM
# 96                                  -10         148             MEDIUM
# 97                                  -33         149                LOW
# 98                                  -23         151                LOW
# 99                                    2         154                LOW
# 100                                  20         158                LOW
# 101                                 -12         155                LOW
# 102                                  14         162                LOW
# 103                                  22         160                LOW
# 104                                 -12         161                LOW
# 105                                   3         163                LOW
# 106                                   9         164                LOW
# 107                                   8         165                LOW
# 108                                  18         167                LOW
# 109                                   1         168                LOW
# 110                                   1         169                LOW
# 111                                  16         170                LOW
# 112                                 -22         171                LOW
# 113                                   5         174                LOW
# 114                                  13         177                LOW
# 115                                  -1         176                LOW
# 116                                   4         182                LOW
# 117                                   4         182                LOW
# 118                                   5         184                LOW
# 119                                  -8         185                LOW
# 120                                 -19         186                LOW
# 121                                   1         187                LOW
#
#            ...         Inequality of Outcomes  \
# 0          ...                             7%
# 1          ...                             8%
# 2          ...                             6%
# 3          ...                             8%
# 4          ...                             7%
# 5          ...                             4%
# 6          ...                             8%
# 7          ...                             5%
# 8          ...                             9%
# 9          ...                             8%
# 10         ...                             6%
# 11         ...                             9%
# 12         ...                             9%
# 13         ...                             8%
# 14         ...                             7%
# 15         ...                             9%
# 16         ...                             9%
# 17         ...                             6%
# 18         ...                             7%
# 19         ...                            10%
# 20         ...                            12%
# 21         ...                            10%
# 22         ...                             9%
# 23         ...                            16%
# 24         ...                            12%
# 25         ...                            12%
# 26         ...                            13%
# 27         ...                            11%
# 28         ...                            11%
# 29         ...                            14%
# ..         ...                            ...
# 92         ...                            28%
# 93         ...                            27%
# 94         ...                            32%
# 95         ...                            38%
# 96         ...                            40%
# 97         ...                            41%
# 98         ...                            44%
# 99         ...                            47%
# 100        ...                            37%
# 101        ...                            37%
# 102        ...                            37%
# 103        ...                            36%
# 104        ...                            42%
# 105        ...                            33%
# 106        ...                            37%
# 107        ...                            41%
# 108        ...                            43%
# 109        ...                            44%
# 110        ...                            43%
# 111        ...                            45%
# 112        ...                            42%
# 113        ...                            36%
# 114        ...                            38%
# 115        ...                            50%
# 116        ...                            43%
# 117        ...                            42%
# 118        ...                            48%
# 119        ...                            43%
# 120        ...                            51%
# 121        ...                            40%
#
#     Inequality-adjusted Life Expectancy  Inequality-adjusted Wellbeing  \
# 0                                  78.6                            7.4
# 1                                  78.6                            6.9
# 2                                  79.4                            7.6
# 3                                  77.6                            6.4
# 4                                  76.8                            7.2
# 5                                  78.2                            7.5
# 6                                  77.5                            6.7
# 7                                  79.8                            7.4
# 8                                  77.8                            7.1
# 9                                  77.7                            6.9
# 10                                 79.1                            7.4
# 11                                 76.8                            6.6
# 12                                 80.6                            5.6
# 13                                 78.7                            6.8
# 14                                 79.0                            6.7
# 15                                 78.5                            6.3
# 16                                 77.2                            6.6
# 17                                 77.6                            7.2
# 18                                 78.0                            7.1
# 19                                 77.1                            5.7
# 20                                 80.2                            5.3
# 21                                 79.3                            5.9
# 22                                 75.5                            5.9
# 23                                 77.6                            4.5
# 24                                 72.6                            5.0
# 25                                 76.6                            5.7
# 26                                 76.6                            5.5
# 27                                 72.9                            5.5
# 28                                 68.8                            5.4
# 29                                 74.9                            6.1
# ..                                  ...                            ...
# 92                                 54.2                            3.5
# 93                                 55.3                            3.8
# 94                                 48.4                            4.0
# 95                                 41.0                            4.1
# 96                                 44.1                            4.6
# 97                                 31.8                            4.4
# 98                                 30.9                            5.2
# 99                                 33.1                            3.7
# 100                                36.9                            4.6
# 101                                41.5                            4.5
# 102                                44.3                            3.0
# 103                                43.3                            3.7
# 104                                32.6                            4.3
# 105                                49.1                            3.3
# 106                                42.9                            4.0
# 107                                36.8                            3.9
# 108                                39.6                            2.4
# 109                                37.3                            2.8
# 110                                38.3                            3.4
# 111                                40.4                            3.5
# 112                                41.4                            3.8
# 113                                43.8                            4.2
# 114                                40.3                            4.1
# 115                                28.2                            4.0
# 116                                34.5                            4.5
# 117                                37.2                            3.3
# 118                                33.0                            3.0
# 119                                36.5                            3.6
# 120                                27.3                            3.7
# 121                                38.9                            3.5
#
#      Happy Planet Index  GDP/capita   Population        GINI index  \
# 0                  36.8   $101,564     5,018,573              25.9
# 1                  21.2    $67,646    22,728,254  Data unavailable
# 2                  34.3    $83,209     7,996,861              31.6
# 3                  29.8    $44,011    80,425,823  Data unavailable
# 4                  32.7    $57,636     5,591,572              29.1
# 5                  35.3    $49,475    16,754,962                28
# 6                  30.0    $48,977     4,586,897              32.5
# 7                  31.1    $44,259       320,716              26.9
# 8                  23.9    $52,738    34,751,476  Data unavailable
# 9                  31.3    $39,505     4,408,100  Data unavailable
# 10                 28.0    $57,134     9,519,374              27.3
# 11                 31.9    $41,295    63,700,300              32.6
# 12                 28.3    $46,679   127,561,489  Data unavailable
# 13                 28.8    $32,819     7,910,500  Data unavailable
# 14                 13.2   $105,447       530,946              34.8
# 15                 30.4    $40,850    65,639,975              33.1
# 16                 23.7    $44,731    11,128,246              27.6
# 17                 31.3    $47,416     5,413,971              27.1
# 18                 30.5    $48,324     8,429,991              30.5
# 19                 24.6    $22,478     2,057,159              25.6
# 20                 28.1    $34,844    59,539,717              35.2
# 21                 36.0    $28,648    46,773,055              35.9
# 22                 27.3    $19,641    10,510,785              26.1
# 23                 23.6    $22,243    11,045,011              36.7
# 24                 17.9    $17,491     1,322,696              33.2
# 25                 30.7    $28,868     1,129,303              34.3
# 26                 29.0    $21,176       419,455  Data unavailable
# 27                 27.5    $13,142    38,063,164              32.4
# 28                 21.0    $14,343     2,987,773              35.2
# 29                 31.7    $15,253    17,388,437  Data unavailable
# ..                  ...         ...          ...               ...
# 92                 25.6       $946    14,832,255              30.8
# 93                 30.5       $685    27,500,515  Data unavailable
# 94                 24.7     $1,421    52,543,841  Data unavailable
# 95                 24.2     $1,185    42,542,978  Data unavailable
# 96                 31.5     $1,266   177,392,252  Data unavailable
# 97                 15.5     $3,989     1,231,694  Data unavailable
# 98                 22.2     $2,740   168,240,403  Data unavailable
# 99                 16.7     $1,222    21,659,488  Data unavailable
# 100                22.1       $851    14,565,482  Data unavailable
# 101                18.0     $1,283     3,777,067  Data unavailable
# 102                19.6       $667    10,817,350  Data unavailable
# 103                23.1       $750       733,661  Data unavailable
# 104                16.7     $1,159     2,057,331  Data unavailable
# 105                21.9     $1,019    13,780,108  Data unavailable
# 106                28.6       $767    10,288,828              60.8
# 107                19.4       $656    35,400,620              42.4
# 108                13.2       $580     6,745,581  Data unavailable
# 109                13.4       $808    10,049,792  Data unavailable
# 110                20.2       $691    29,726,803  Data unavailable
# 111                22.1       $270    15,700,436  Data unavailable
# 112                16.4     $1,587       853,069              45.1
# 113                26.7       $470    92,191,211  Data unavailable
# 114                22.2       $414     4,190,155  Data unavailable
# 115                15.3       $619     6,043,157  Data unavailable
# 116                23.7       $565    25,732,928  Data unavailable
# 117                15.9       $487    11,628,767              33.7
# 118                15.6       $244    10,124,572  Data unavailable
# 119                17.9       $673    16,590,813  Data unavailable
# 120                12.8       $973    12,715,465  Data unavailable
# 121                16.8       $394    17,635,782  Data unavailable
#
#      Country Code  GDP Volatility  Median Inflation
# 0             NOR            1.81             3.40%
# 1             AUS            1.73             3.30%
# 2             CHE            1.57             1.80%
# 3             DEU            1.94             1.50%
# 4             DNK            2.29             3.40%
# 5             NLD            2.27             2.50%
# 6             IRL            4.47             3.80%
# 7             ISL            4.25             7.30%
# 8             CAN            2.15             2.70%
# 9             NZL            2.45             3.40%
# 10            SWE            2.19             3.40%
# 11            GBR            2.04             2.20%
# 12            JPN            3.83             2.00%
# 13            ISR            3.43             7.90%
# 14            LUX            3.31             2.70%
# 15            FRA            2.03             2.70%
# 16            BEL            2.00             2.80%
# 17            FIN            3.07             3.40%
# 18            AUT            1.97             3.00%
# 19            SVN            3.12             4.60%
# 20            ITA            2.66             4.00%
# 21            ESP            3.02             5.00%
# 22            CZE            3.77             2.50%
# 23            GRC            4.48             4.30%
# 24            EST            5.67             4.10%
# 25            CYP            4.55             3.00%
# 26            MLT            4.08             2.30%
# 27            POL            2.63             7.00%
# 28            LTU            5.08             2.90%
# 29            CHL            4.55            14.70%
# ..            ...             ...               ...
# 92            KHM            8.94             3.90%
# 93            NPL            2.70             8.40%
# 94            MMR            5.37             7.70%
# 95            KEN            4.50             9.30%
# 96            PAK            2.35             7.20%
# 97            SWZ            4.76             8.10%
# 98            NGA            8.16            11.50%
# 99            CMR            5.49             4.00%
# 100           ZWE            7.37            11.70%
# 101           MRT            5.93             5.60%
# 102           RWA           10.17             6.20%
# 103           COM            2.97             3.40%
# 104           LSO            5.77            11.20%
# 105           SEN            3.55             2.20%
# 106           HTI            2.42             9.00%
# 107           UGA            2.97             8.60%
# 108           TGO            5.66             2.90%
# 109           BEN            3.04             2.60%
# 110           AFG            5.60             7.20%
# 111           MWI            4.91            15.10%
# 112           DJI            2.20             2.90%
# 113           ETH            6.60             7.60%
# 114           LBR           19.50             8.50%
# 115           SLE            7.12            11.50%
# 116           MOZ            6.88            12.70%
# 117           GIN            2.08            15.30%
# 118           BDI            5.62             7.90%
# 119           BFA            3.11             2.30%
# 120           TCD            8.40             3.70%
# 121           NER            5.77             2.60%
#
# [122 rows x 26 columns]

# %%
# graph Happy Planet Index vs GDP per capita
onlylow = merged_df2.loc[merged_df2['Development Bucket'] == "LOW", :]
onlymed = merged_df2.loc[merged_df2['Development Bucket'] == "MEDIUM", :]
onlyhigh = merged_df2.loc[merged_df2['Development Bucket'] == "HIGH", :]
onlyvhigh = merged_df2.loc[merged_df2['Development Bucket'] == "VERY HIGH", :]

xlow = onlylow['GDP/capita']
xmed = onlymed['GDP/capita']
xhigh = onlyhigh['GDP/capita']
xvhigh = onlyvhigh['GDP/capita']

ylow = onlylow['Happy Planet Index']
ymed = onlymed['Happy Planet Index']
yhigh = onlyhigh['Happy Planet Index']
yvhigh = onlyvhigh['Happy Planet Index']

zlow = onlylow['Population']
zmed = onlymed['Population']
zhigh = onlyhigh['Population']
zvhigh = onlyvhigh['Population']

# %%
merged_df2.dtypes
# Out:
# HDI rank                                    int64
# Country                                    object
# Human Development Index (HDI)             float64
# Life expectancy at birth                  float64
# Expected years of schooling               float64
# Mean years of schooling                   float64
# Gross national income (GNI) per capita     object
# GNI per capita rank minus HDI rank          int64
# HDI rank.1                                  int64
# Development Bucket                         object
# HPI Rank                                  float64
# Region                                     object
# Average Life \nExpectancy                 float64
# Average Wellbeing\n(0-10)                 float64
# Happy Life Years                          float64
# Footprint\n(gha/capita)                   float64
# Inequality of Outcomes                     object
# Inequality-adjusted Life Expectancy       float64
# Inequality-adjusted Wellbeing             float64
# Happy Planet Index                        float64
# GDP/capita                                 object
# Population                                 object
# GINI index                                 object
# Country Code                               object
# GDP Volatility                            float64
# Median Inflation                           object
# dtype: object

# %%
df33 = merged_df2[["Country","Happy Planet Index","GDP/capita", "Development Bucket", "Population", "GDP Volatility", "Median Inflation"]]
df33 = df33.set_index('GDP/capita')
df33 = df33.sort_index(ascending=True)
df33 = df33.reset_index()
df33['GDP/capita'] = df33['GDP/capita'].str.replace(',','')
df33['GDP/capita'] = df33['GDP/capita'].str.replace('$','').astype('float')
df33['Population'] = df33['Population'].str.replace(',','')
df33['Population'] = df33['Population'].str.replace('$','').astype('float')
df33['Median Inflation'] = df33['Median Inflation'].str.replace('%','').astype('float')
df33.head()
# Out:
#    GDP/capita   Country  Happy Planet Index Development Bucket   Population  \
# 0      1019.0   Senegal                21.9                LOW   13780108.0
# 1      1159.0   Lesotho                16.7                LOW    2057331.0
# 2      1185.0     Kenya                24.2             MEDIUM   42542978.0
# 3      1222.0  Cameroon                16.7                LOW   21659488.0
# 4      1266.0  Pakistan                31.5             MEDIUM  177392252.0
#
#    GDP Volatility  Median Inflation
# 0            3.55               2.2
# 1            5.77              11.2
# 2            4.50               9.3
# 3            5.49               4.0
# 4            2.35               7.2

# %%
# graph Happy Planet Index vs GDP per capita
onlylow = df33.loc[merged_df2['Development Bucket'] == "LOW", :]
onlymed = df33.loc[merged_df2['Development Bucket'] == "MEDIUM", :]
onlyhigh = df33.loc[merged_df2['Development Bucket'] == "HIGH", :]
onlyvhigh = df33.loc[merged_df2['Development Bucket'] == "VERY HIGH", :]

xlow = onlylow['GDP/capita']
xmed = onlymed['GDP/capita']
xhigh = onlyhigh['GDP/capita']
xvhigh = onlyvhigh['GDP/capita']

ylow = onlylow['Happy Planet Index']
ymed = onlymed['Happy Planet Index']
yhigh = onlyhigh['Happy Planet Index']
yvhigh = onlyvhigh['Happy Planet Index']

zlow = onlylow['Population']
zmed = onlymed['Population']
zhigh = onlyhigh['Population']
zvhigh = onlyvhigh['Population']

# %%
l = plt.scatter(xlow, ylow, marker="o", facecolors="red", edgecolors="black", s=zlow**(1/float(4)), alpha=.75)
m = plt.scatter(xmed, ymed, marker="o", facecolors="gold", edgecolors="black", s=zmed**(1/float(4)), alpha=.75)
h = plt.scatter(xhigh, yhigh, marker="o", facecolors="lawngreen", edgecolors="black", s=zhigh**(1/float(4)), alpha=.75)
vh = plt.scatter(xvhigh, yvhigh, marker="o", facecolors="blue", edgecolors="black", s=zvhigh**(1/float(4)), alpha=.75)
plt.title("Happiness vs GDP per Capita")
plt.xlabel("GDP/capita ($PPP)")
plt.ylabel("Happy Planet Index")

# Create a legend
lgnd = plt.legend((l, m, h, vh), ('Low', 'Medium', 'High', 'Very High'),loc="best",title="HDI Buckets")
for handle in lgnd.legendHandles:
    handle.set_sizes([36.0])
    
# Incorporate a text label regarding circle size
textstr = 'Note: Bubble size reflects population.'
plt.text(120000,40,textstr, fontsize=10)

# Save Figure
plt.savefig("Images/HappinessVsGDP.png")

# %%
# graph Happy Planet Index vs GDP per capita
onlylow = df33.loc[merged_df2['Development Bucket'] == "LOW", :]
onlymed = df33.loc[merged_df2['Development Bucket'] == "MEDIUM", :]
onlyhigh = df33.loc[merged_df2['Development Bucket'] == "HIGH", :]
onlyvhigh = df33.loc[merged_df2['Development Bucket'] == "VERY HIGH", :]

xlow = onlylow['GDP/capita']
xmed = onlymed['GDP/capita']
xhigh = onlyhigh['GDP/capita']
xvhigh = onlyvhigh['GDP/capita']

ylow = onlylow['GDP Volatility']
ymed = onlymed['GDP Volatility']
yhigh = onlyhigh['GDP Volatility']
yvhigh = onlyvhigh['GDP Volatility']

zlow = onlylow['Population']
zmed = onlymed['Population']
zhigh = onlyhigh['Population']
zvhigh = onlyvhigh['Population']

# regression line
#(slope, intercept, _, _, _) = linregress(xlow, ylow)
#fit = slope * xlow + intercept
#ax.plot(xlow, fit, 'b--')

# %%
l = plt.scatter(xlow, ylow, marker="o", facecolors="red", edgecolors="black", s=zlow**(1/float(4)), alpha=.75)
m = plt.scatter(xmed, ymed, marker="o", facecolors="gold", edgecolors="black", s=zmed**(1/float(4)), alpha=.75)
h = plt.scatter(xhigh, yhigh, marker="o", facecolors="lawngreen", edgecolors="black", s=zhigh**(1/float(4)), alpha=.75)
vh = plt.scatter(xvhigh, yvhigh, marker="o", facecolors="blue", edgecolors="black", s=zvhigh**(1/float(4)), alpha=.75)
plt.title("Happiness vs GDP per Capita")
plt.xlabel("GDP/capita ($PPP)")
plt.ylabel("Happy Planet Index")

# Create a legend
lgnd = plt.legend((l, m, h, vh), ('Low', 'Medium', 'High', 'Very High'),loc="best",title="HDI Buckets")
for handle in lgnd.legendHandles:
    handle.set_sizes([36.0])
    
# Incorporate a text label regarding circle size
textstr = 'Note: Bubble size reflects population.'
plt.text(120000,40,textstr, fontsize=10)

# Save Figure
plt.savefig("Images/HappinessVsGDP.png")

# %%
plt.scatter(merged_df2["Happy Planet Index"], merged_df2["Median Inflation"], marker="o", facecolors="red", edgecolors="black", s=16, alpha=.75)


plt.title("Happiness vs Inflation")
plt.xlabel("Happy Planet Index")
plt.ylabel("Inflation")

import matplotlib.pyplot as mplot
cur_axes = mplot.gca()
cur_axes.axes.get_yaxis().set_ticks([])
cur_axes = mplot.gca()
cur_axes.axes.get_yaxis().set_ticklabels([])
                           
plt.show()
